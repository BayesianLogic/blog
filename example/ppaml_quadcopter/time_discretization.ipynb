# %%
from automobile_data import read_datadata_dir = "./data/automobile/1_straight/data/ground/"data = read_data(data_dir)

# %%
gps_data = [d for d in data if d.gps_latitude is not None]deltas = [gps_data[i].time - gps_data[i-1].time for i in xrange(1, len(gps_data))]_ = hist(deltas, bins=100)

# %%
control_data = [d for d in data if d.velocity is not None]deltas = [control_data[i].time - control_data[i-1].time for i in xrange(1, len(control_data))]_ = hist(deltas, bins=100)

# %%
laser_data = [d for d in data if d.laser is not None]deltas = [laser_data[i].time - laser_data[i-1].time for i in xrange(1, len(laser_data))]_ = hist(deltas, bins=100)
